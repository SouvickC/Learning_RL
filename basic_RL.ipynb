# %%
# !pip install gym-walk
# Out:
# ERROR: Could not find a version that satisfies the requirement gym-walk (from versions: none)
# ERROR: No matching distribution found for gym-walk

# %%
import gymnasium as gym
# import gym_walk  # This line is mandatory to register the environment

P = gym.make('FrozenLake-v1').env.unwrapped.P
P
# Out:
# {0: {0: [(0.33333333333333337, 0, 0, False),
#    (0.3333333333333333, 0, 0, False),
#    (0.33333333333333337, 4, 0, False)],
#   1: [(0.33333333333333337, 0, 0, False),
#    (0.3333333333333333, 4, 0, False),
#    (0.33333333333333337, 1, 0, False)],
#   2: [(0.33333333333333337, 4, 0, False),
#    (0.3333333333333333, 1, 0, False),
#    (0.33333333333333337, 0, 0, False)],
#   3: [(0.33333333333333337, 1, 0, False),
#    (0.3333333333333333, 0, 0, False),
#    (0.33333333333333337, 0, 0, False)]},
#  1: {0: [(0.33333333333333337, 1, 0, False),
#    (0.3333333333333333, 0, 0, False),
#    (0.33333333333333337, 5, 0, True)],
#   1: [(0.33333333333333337, 0, 0, False),
#    (0.3333333333333333, 5, 0, True),
#    (0.33333333333333337, 2, 0, False)],
#   2: [(0.33333333333333337, 5, 0, True),
#    (0.3333333333333333, 2, 0, False),
#    (0.33333333333333337, 1, 0, False)],
#   3: [(0.33333333333333337, 2, 0, False),
#    (0.3333333333333333, 1, 0, False),
# ...

# %%
env = gym.make('BanditWalk-v2')
P = env.unwrapped.P
# Out:
# ---------------------------------------------------------------------------
# NameNotFound                              Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 env = gym.make('BanditWalk-v2')
#       2 P = env.unwrapped.P
#
# File c:\Users\Lenovo\miniconda3\envs\openui\Lib\site-packages\gymnasium\envs\registration.py:681, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     678     assert isinstance(id, str)
#     680     # The environment name can include an unloaded module in "module:env_name" style
# --> 681     env_spec = _find_spec(id)
#     683 assert isinstance(env_spec, EnvSpec)
#     685 # Update the env spec kwargs with the `make` kwargs
#
# File c:\Users\Lenovo\miniconda3\envs\openui\Lib\site-packages\gymnasium\envs\registration.py:526, in _find_spec(env_id)
#     520     logger.warn(
#     521         f"Using the latest versioned environment `{new_env_id}` "
#     522         f"instead of the unversioned environment `{env_name}`."
# ...
